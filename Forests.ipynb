# %%
#!wget --header="Host: storage.googleapis.com" --header="User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8" --header="Accept-Language: en-IN,en-US;q=0.9,en-GB;q=0.8,en;q=0.7" "https://storage.googleapis.com/kaggle-competitions-data/kaggle/6322/train-jpg.tar.7z?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1537272351&Signature=TxM9rv1QY6UTK3PHigGtyHSm39VT8vfGkvgwYakdItBlVtIeEfgQtngWDCd8SDfiRmhOhPhZmJNtlsLAS6%2F2mVfy32wkMPurGNaOrRt6GBaT8gs9VbtL8F7pziKS2rxm7SyvlgAZNShr7lYjrJAssHi4wJKrOaB%2FNpc9PSTqrQOMORMXGejRuX1%2BEXxUTD8XXmmr%2FYTOSVjEbnAVpBowC%2FB1S9peTubu3paD%2BUU4%2FrhEyDDgkDILZ9xFc%2F7wwRXsrU3D1dZ9Wq5i1r4RwBYUonwjed9BYhNBT0K5O8qHccyh7PHJK3DCFAz0wGw8oA%2F5mNnXFYnxFrjbx4XFP5Apjg%3D%3D" -O "train-jpg.tar.7z" -c
# Out:
# --2018-09-15 13:27:56--  https://storage.googleapis.com/kaggle-competitions-data/kaggle/6322/train-jpg.tar.7z?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1537272351&Signature=TxM9rv1QY6UTK3PHigGtyHSm39VT8vfGkvgwYakdItBlVtIeEfgQtngWDCd8SDfiRmhOhPhZmJNtlsLAS6%2F2mVfy32wkMPurGNaOrRt6GBaT8gs9VbtL8F7pziKS2rxm7SyvlgAZNShr7lYjrJAssHi4wJKrOaB%2FNpc9PSTqrQOMORMXGejRuX1%2BEXxUTD8XXmmr%2FYTOSVjEbnAVpBowC%2FB1S9peTubu3paD%2BUU4%2FrhEyDDgkDILZ9xFc%2F7wwRXsrU3D1dZ9Wq5i1r4RwBYUonwjed9BYhNBT0K5O8qHccyh7PHJK3DCFAz0wGw8oA%2F5mNnXFYnxFrjbx4XFP5Apjg%3D%3D
# Resolving storage.googleapis.com (storage.googleapis.com)... 216.58.217.48, 2607:f8b0:4005:802::2010
# Connecting to storage.googleapis.com (storage.googleapis.com)|216.58.217.48|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 629296207 (600M) [application/x-7z-compressed]
# Saving to: ‘train-jpg.tar.7z’
#
# train-jpg.tar.7z    100%[===================>] 600.14M   129MB/s    in 4.7s
#
# ...

# %%
#!7za x train-jpg.tar.7z
#!tar -xf train-jpg.tar
# Out:
# 7-Zip (A) [64] 9.20  Copyright (c) 1999-2010 Igor Pavlov  2010-11-18
# p7zip Version 9.20 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,4 CPUs)
#
# Processing archive: train-jpg.tar.7z
#
# Extracting  train-jpg.tar
#
# Everything is Ok
#
# Size:       665753600
# Compressed: 629296207

# %%
#ls data
# Out:
# test-jpg/  train-jpg/  train_v2.csv

# %%
#!wget --header="Host: storage.googleapis.com" --header="User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8" --header="Accept-Language: en-IN,en-US;q=0.9,en-GB;q=0.8,en;q=0.7" "https://storage.googleapis.com/kaggle-competitions-data/kaggle/6322/test-jpg.tar.7z?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1537272264&Signature=Nj8klHnHJYYPsx9YcvNQmddUsrRd8cXcKc2LkT4y2s6aL0eeMRKgZFfjopfqV5mQ8Y%2BSky7A4TcMCM2vspdjeO%2Btv4eJuR%2BwJ1n9E%2BFl9%2Be9cD4NZuF4z4%2FZHI1yJtf4HfDv0%2B6tD8ShYSTGTph%2BzALAqXaCYiuwp3Ro%2BOHtJdbda%2BlFAE9co4muO6%2BztUzbRk2RHWAIRM4ckhSCaacCNU2Q%2FV%2FqJZxry%2BycAIMuCKz3BFbWEcpLzWZYlFHYf4hZPAWWi2FzE7mjsU9DeLiEyAJ13tyq4hXDTg87Bqmxd2JP1uHkyGq%2FNTMs9HsjSzsdXK6torruHuMylQyZdVadPg%3D%3D" -O "test-jpg.tar.7z" -c
# Out:
# --2018-09-15 13:31:20--  https://storage.googleapis.com/kaggle-competitions-data/kaggle/6322/test-jpg.tar.7z?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1537272264&Signature=Nj8klHnHJYYPsx9YcvNQmddUsrRd8cXcKc2LkT4y2s6aL0eeMRKgZFfjopfqV5mQ8Y%2BSky7A4TcMCM2vspdjeO%2Btv4eJuR%2BwJ1n9E%2BFl9%2Be9cD4NZuF4z4%2FZHI1yJtf4HfDv0%2B6tD8ShYSTGTph%2BzALAqXaCYiuwp3Ro%2BOHtJdbda%2BlFAE9co4muO6%2BztUzbRk2RHWAIRM4ckhSCaacCNU2Q%2FV%2FqJZxry%2BycAIMuCKz3BFbWEcpLzWZYlFHYf4hZPAWWi2FzE7mjsU9DeLiEyAJ13tyq4hXDTg87Bqmxd2JP1uHkyGq%2FNTMs9HsjSzsdXK6torruHuMylQyZdVadPg%3D%3D
# Resolving storage.googleapis.com (storage.googleapis.com)... 216.58.193.80, 2607:f8b0:4005:80b::2010
# Connecting to storage.googleapis.com (storage.googleapis.com)|216.58.193.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 632362315 (603M) [application/x-7z-compressed]
# Saving to: ‘test-jpg.tar.7z’
#
# test-jpg.tar.7z     100%[===================>] 603.07M   108MB/s    in 5.4s
#
# ...

# %%
#!7za x test-jpg.tar.7z
#!tar -xf test-jpg.tar
# Out:
# 7-Zip (A) [64] 9.20  Copyright (c) 1999-2010 Igor Pavlov  2010-11-18
# p7zip Version 9.20 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,4 CPUs)
#
# Processing archive: test-jpg.tar.7z
#
# Extracting  test-jpg.tar
#
# Everything is Ok
#
# Size:       668989440
# Compressed: 632362315

# %%
#!mkdir data

# %%
#!mv train-jpg/ ./data/train-jpg

# %%
#!mv test-jpg/ ./data/test-jpg

# %%
#!mv train_v2.csv ./data/train_v2.csv

# %%
PATH = "data/"

# %%
ls {PATH}
# Out:
# models/  test-jpg/  tmp/  train-jpg/  train_v2.csv  val-jpg/

# %%
from fastai.conv_learner import *
from fastai.plots import *

# %%
list_paths = [f"{PATH}train-jpg/train_0.jpg", f"{PATH}train-jpg/train_1.jpg"]
titles=["haze primary", "agriculture clear primary water"]
plots_from_files(list_paths, titles=titles, maintitle="Multi-label classification")

# %%
from fastai.imports import *
from fastai.transforms import *
from fastai.dataset import *
from sklearn.metrics import fbeta_score
import warnings

def f2(preds, targs, start=0.17, end=0.24, step=0.01):
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        return max([fbeta_score(targs, (preds>th), 2, average='samples')
                    for th in np.arange(start,end,step)])

def opt_th(preds, targs, start=0.17, end=0.24, step=0.01):
    ths = np.arange(start,end,step)
    idx = np.argmax([fbeta_score(targs, (preds>th), 2, average='samples')
                for th in ths])
    return ths[idx]

def get_data(path, tfms,bs,  n, cv_idx):
    val_idxs = get_cv_idxs(n, cv_idx)
    return ImageClassifierData.from_csv(path, 'train-jpg', f'{path}train_v2.csv', bs, tfms,
                                 suffix='.jpg', val_idxs=val_idxs, test_name='test-jpg')

def get_data_zoom(f_model, path, sz, bs, n, cv_idx):
    tfms = tfms_from_model(f_model, sz, aug_tfms=transforms_top_down, max_zoom=1.05)
    return get_data(path, tfms, bs, n, cv_idx)

def get_data_pad(f_model, path, sz, bs, n, cv_idx):
    transforms_pt = [RandomRotateZoom(9, 0.18, 0.1), RandomLighting(0.05, 0.1), RandomDihedral()]
    tfms = tfms_from_model(f_model, sz, aug_tfms=transforms_pt, pad=sz//12)
    return get_data(path, tfms, bs, n, cv_idx)

# %%
metrics=[f2]
f_model = resnet34
label_csv = f'{PATH}train_v2.csv'
n = len(list(open(label_csv)))-1
val_idxs = get_cv_idxs(n)

# %%
def get_data(sz):
    tfms = tfms_from_model(f_model, sz, aug_tfms=transforms_top_down, max_zoom=1.05)
    return ImageClassifierData.from_csv(PATH, 'train-jpg', label_csv, tfms=tfms,
                    suffix='.jpg', val_idxs=val_idxs, test_name='test-jpg')

# %%
data = get_data(256)

# %%
x,y = next(iter(data.val_dl))

# %%
x
# Out:
# ( 0 , 0 ,.,.) =
#  -1.2959 -1.2274 -1.1418  ...  -1.3130 -1.2103 -1.0904
#  -1.2445 -1.2103 -1.1418  ...  -1.3987 -1.3644 -1.2788
#  -1.1932 -1.1760 -1.1418  ...  -1.3987 -1.4500 -1.4329
#            ...             ⋱             ...
#  -0.5253 -0.4739 -0.4054  ...  -0.8335 -0.6965 -0.5767
#  -0.5596 -0.4911 -0.4054  ...  -0.7137 -0.5767 -0.4739
#  -0.5767 -0.4911 -0.4054  ...  -0.6281 -0.5082 -0.4054
#
# ( 0 , 1 ,.,.) =
#  -0.9503 -0.9153 -0.8452  ...  -1.0728 -1.0028 -0.8978
#  -0.9328 -0.8978 -0.8452  ...  -1.1253 -1.0728 -0.9678
#  -0.9153 -0.8803 -0.8452  ...  -1.1604 -1.1253 -1.0553
#            ...             ⋱             ...
#  -0.3025 -0.2675 -0.2150  ...  -0.4951 -0.4076 -0.3375
#  -0.3200 -0.2850 -0.2325  ...  -0.4251 -0.3375 -0.2675
#  -0.3375 -0.3025 -0.2325  ...  -0.4076 -0.3200 -0.2500
#
# ( 0 , 2 ,.,.) =
#  -0.8284 -0.8110 -0.7587  ...  -0.9504 -0.8633 -0.7587
#  -0.7936 -0.7761 -0.7587  ...  -0.9853 -0.9504 -0.8807
# ...

# %%
len(data.classes)
# Out:
# 17

# %%
list(zip(data.classes, y[0]))
# Out:
# [('agriculture', 1.0),
#  ('artisinal_mine', 0.0),
#  ('bare_ground', 0.0),
#  ('blooming', 0.0),
#  ('blow_down', 0.0),
#  ('clear', 1.0),
#  ('cloudy', 0.0),
#  ('conventional_mine', 0.0),
#  ('cultivation', 0.0),
#  ('habitation', 0.0),
#  ('haze', 0.0),
#  ('partly_cloudy', 0.0),
#  ('primary', 1.0),
#  ('road', 0.0),
#  ('selective_logging', 0.0),
#  ('slash_burn', 0.0),
#  ('water', 1.0)]

# %%
data.classes
# Out:
# ['agriculture',
#  'artisinal_mine',
#  'bare_ground',
#  'blooming',
#  'blow_down',
#  'clear',
#  'cloudy',
#  'conventional_mine',
#  'cultivation',
#  'habitation',
#  'haze',
#  'partly_cloudy',
#  'primary',
#  'road',
#  'selective_logging',
#  'slash_burn',
#  'water']

# %%
plt.imshow(data.val_ds.denorm(to_np(x))[0]*1.4);

# %%
sz=64
data = get_data(sz)

# %%
data = data.resize(int(sz*1.3), 'tmp')

# %%
learn = ConvLearner.pretrained(f_model, data, metrics=metrics)

# %%
??ConvLearner.pretrained

# %%
lrf=learn.lr_find()
learn.sched.plot()
# Out:
# ...
# epoch      trn_loss   val_loss   f2
#     0      0.22301    0.252672   0.832134

# %%
lr = 0.2

# %%
learn.fit(lr, 3, cycle_len=1, cycle_mult=2)
# Out:
# ...
# epoch      trn_loss   val_loss   f2
#     0      0.147565   0.134647   0.880749
#     1      0.140445   0.129556   0.885861
#     2      0.138865   0.127142   0.889865
#     3      0.136365   0.126368   0.888946
#     4      0.136599   0.1245     0.891845
#     5      0.131704   0.123518   0.892959
#     6      0.130973   0.123005   0.893556
# [array([0.123]), 0.8935562631920694]

# %%
lrs = np.array([lr/9,lr/3,lr])

# %%
learn.unfreeze()
learn.fit(lrs, 3, cycle_len=1, cycle_mult=2)
# Out:
# ...
# epoch      trn_loss   val_loss   f2
#     0      0.123747   0.111141   0.907158
#     1      0.118893   0.105666   0.91195
#     2      0.109046   0.102385   0.913635
#     3      0.112002   0.107701   0.907952
#     4      0.106899   0.10055    0.91517
#     5      0.10067    0.098373   0.916686
#     6      0.101655   0.097409   0.918615
# [array([0.09741]), 0.9186151732878208]

# %%
learn.save(f'{sz}')

# %%
learn.sched.plot_loss()

# %%
learn.load(f'{sz}')

# %%
sz=128

# %%
learn.set_data(get_data(sz))
learn.freeze()
learn.fit(lr, 3, cycle_len=1, cycle_mult=2)
learn.save(f'{sz}-frozen')
# Out:
# ...
# epoch      trn_loss   val_loss   f2
#     0      0.098392   0.096757   0.91739
#     1      0.099961   0.096386   0.916764
#     2      0.099875   0.09508    0.918488
#     3      0.100939   0.094584   0.919484
#     4      0.097081   0.093688   0.9209
#     5      0.097454   0.094282   0.919585
#     6      0.093574   0.093325   0.920758

# %%
learn.unfreeze()
learn.fit(lrs, 3, cycle_len=1, cycle_mult=2)
learn.save(f'{sz}')
# Out:
# ...
# epoch      trn_loss   val_loss   f2
#     0      0.094114   0.088411   0.926754
#     1      0.095485   0.088162   0.927418
#     2      0.087725   0.086462   0.928261
#     3      0.092563   0.089178   0.927513
#     4      0.088802   0.086428   0.927571
#     5      0.084997   0.085834   0.928705
#     6      0.08265    0.085604   0.928925

# %%
sz=256

# %%
learn.set_data(get_data(sz))
learn.freeze()
learn.fit(lr, 3, cycle_len=1, cycle_mult=2)
#lea.save(f'{sz}-frozen')
# Out:
# ...
# epoch      trn_loss   val_loss   f2
#     0      0.090925   0.089405   0.924973
#     1      0.089119   0.088107   0.926629
#     2      0.089859   0.088338   0.92641
#     3      0.089616   0.087812   0.926921
#     4      0.089803   0.087577   0.92687
#     5      0.08781    0.087177   0.927141
#     6      0.088099   0.086975   0.927182
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-151-8b1da5e21e65> in <module>()
#       2 learn.freeze()
#       3 learn.fit(lr, 3, cycle_len=1, cycle_mult=2)
# ----> 4 lea.save(f'{sz}-frozen')
#
# NameError: name 'lea' is not defined

# %%
learn.save(f"{sz}-frozen")

# %%
learn.unfreeze()
learn.fit(lrs, 3, cycle_len=1)#, cycle_mult=2)
learn.save(f'{sz}')
# Out:
# ...
#   1%|▏         | 7/506 [00:13<15:55,  1.92s/it, loss=0.0948]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-177-0fd51c8ccc34> in <module>()
#       1 learn.unfreeze()
# ----> 2 learn.fit(lrs, 3, cycle_len=1)#, cycle_mult=2)
#       3 learn.save(f'{sz}')
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/fastai/learner.py in fit(self, lrs, n_cycle, wds, **kwargs)
#     285         self.sched = None
#     286         layer_opt = self.get_layer_opt(lrs, wds)
# --> 287         return self.fit_gen(self.model, self.data, layer_opt, n_cycle, **kwargs)
#     288
#     289     def warm_up(self, lr, wds=None):
#
# ...

# %%
sz = 128

# %%
learn.load(f'{sz}')

# %%
multi_preds, y = learn.TTA()
preds = np.mean(multi_preds, 0)

# %%
f2(preds,y)
# Out:
# 0.9088222108097334

# %%
#datax = ImageClassifierData.from_paths(f'{PATH}val-jpg', tfms=tfms_from_model(f_model, 128))

# %%
from PIL import Image

# %%
q = Image.open('data/val-jpg/thumb.png')
q.size
# Out:
# (512, 512)

# %%
tuplimage.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-8f797f04f499> in <module>()
# ----> 1 tuplimage.shape
#
# NameError: name 'tuplimage' is not defined

# %%
model=f_model()
model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#   (relu): ReLU(inplace)
#   (maxpool): MaxPool2d(kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), dilation=(1, 1), ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#       (relu): ReLU(inplace)
# ...

# %%
Image.open("data/val-jpg/thumb+2.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7EFC214255F8>

# %%
file_1='data/val-jpg/thumb+2.png'

# %%
trn_tfms,val_tfms=tfms_from_model(f_model,64)
ds=FilesIndexArrayDataset([file_1],np.array([0]),val_tfms,'')
dl=DataLoader(ds)
preds=learn.predict_dl(dl)
list(zip(data.classes,preds[0]))
# Out:
# [('agriculture', 0.85443234),
#  ('artisinal_mine', 0.011742294),
#  ('bare_ground', 0.024279462),
#  ('blooming', 0.0008059708),
#  ('blow_down', 0.0011320114),
#  ('clear', 0.5315978),
#  ('cloudy', 0.00049284525),
#  ('conventional_mine', 0.00052156294),
#  ('cultivation', 0.28499484),
#  ('habitation', 0.36609498),
#  ('haze', 0.00124525),
#  ('partly_cloudy', 0.5892403),
#  ('primary', 0.9967801),
#  ('road', 0.037072793),
#  ('selective_logging', 0.0007728361),
#  ('slash_burn', 0.0075233243),
#  ('water', 0.88446414)]

# %%
x,_=next(iter(it1.aug_dl))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-68d4fdf85440> in <module>()
# ----> 1 x,_=next(iter(it1.aug_dl))
#
# NameError: name 'it1' is not defined

# %%
def predict(abs_path,size):
    file_1=abs_path
    trn_tfms,val_tfms=tfms_from_model(f_model,size)
    ds=FilesIndexArrayDataset([file_1],np.array([0]),val_tfms,'')
    dl=DataLoader(ds)
    preds=learn.predict_dl(dl)
    return list(zip(data.classes,preds[0]))

# %%
predict("data/val-jpg/thumb+2.png",128)
# Out:
# [('agriculture', 0.8838553),
#  ('artisinal_mine', 0.0054139746),
#  ('bare_ground', 0.034420982),
#  ('blooming', 0.0011517539),
#  ('blow_down', 0.003192571),
#  ('clear', 0.08553138),
#  ('cloudy', 0.0037309423),
#  ('conventional_mine', 0.0022780036),
#  ('cultivation', 0.22290048),
#  ('habitation', 0.41598365),
#  ('haze', 0.008217781),
#  ('partly_cloudy', 0.9258653),
#  ('primary', 0.984798),
#  ('road', 0.22072595),
#  ('selective_logging', 0.0024808852),
#  ('slash_burn', 0.009450702),
#  ('water', 0.51532227)]

# %%
def weighted_predict(tup_pred,ths=0.2):
    preds = []
    danger = ['slash_burn','selective_logging','artisinal_mine','cultivation','agriculture','road']
    #preds = [(2 if label in danger_2 else 1) if pred > th and (label in danger_2 or label in danger_1) else 0\
    #            for label,pred in tup_pred]
    for idx,(label,pred) in enumerate(tup_pred):
        if pred > ths and label in danger:
            preds.append((pred,data.classes[idx]))
    return preds

# %%
weighted_predict(predict("data/val-jpg/thumb+2.png",128),0.1)
# Out:
# [(0.8838553, 'agriculture'), (0.22290048, 'cultivation'), (0.22072595, 'road')]

# %%
import requests

# %%
urls = ["https://api.nasa.gov/planetary/earth/imagery/?lon=75.8904&lat=29.0932&date=2014-05-17&cloud_score=True&api_key=LmyM0s3qTSsgRluRa7qtZuN36tswMqZqlgm9LsKY",
       "https://api.nasa.gov/planetary/earth/imagery/?lon=73.2625&lat=25.03271&date=2014-05-17&cloud_score=True&api_key=LmyM0s3qTSsgRluRa7qtZuN36tswMqZqlgm9LsKY",
       "https://api.nasa.gov/planetary/earth/imagery/?lon=84.9718&lat=22.1906&date=2014-05-17&cloud_score=True&api_key=LmyM0s3qTSsgRluRa7qtZuN36tswMqZqlgm9LsKY"
      ]

# %%
for i,url in enumerate(urls):
    r=requests.get(url)
    if r.status_code==200:
        resp=r.json()
        pic_url=resp['url']
        re=requests.get(pic_url,allow_redirects=True)
        if re.status_code==200:
            file_name='{}.png'.format(i)
            open(file_name,'wb').write(re.content)

# %%
# !ls
# Out:
# 0.png		      Forests.ipynb		test_v2_file_mapping.csv.zip
# 1537075428_44622.png  __MACOSX			thumb.jpg
# 1537075691_23028.png  nasa_model_server_django	torch_model.onnx
# 1.png		      Nvidia_Cloud_EULA.pdf	train-jpg.tar
# 2.png		      predictor.py		train-jpg.tar.7z
# anaconda3	      README			train_v2.csv.zip
# data		      src			tutorials
# examples	      test-jpg.tar
# fastai		      test-jpg.tar.7z

# %%
Image.open('0.png') #punjab
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7EFC211E8630>

# %%
weighted_predict(predict("0.png",128),0.1)
# Out:
# [(0.96244234, 'agriculture'),
#  (0.13158314, 'cultivation'),
#  (0.63345826, 'road')]

# %%
Image.open('1.png') #hissar
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7EFC211E8CC0>

# %%
weighted_predict(predict("1.png",128),0.1)
# Out:
# [(0.8906274, 'agriculture'), (0.8884491, 'road')]

# %%
Image.open('2.png') #rourkela
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7EFC20ABD6A0>

# %%
weighted_predict(predict("2.png",128),0.1)
# Out:
# [(0.7411915, 'agriculture'), (0.15052013, 'cultivation'), (0.60783863, 'road')]
